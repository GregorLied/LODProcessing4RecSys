# %%
from rdflib_hdt import HDTStore
from rdflib import Graph

# Load an HDT file. Missing indexes are generated automatically
# You can provide the index file by putting it in the same directory as the HDT file.
# See https://www.rdfhdt.org/datasets/ for getting the HDT and the index file.
print("Loading HDTStore at ...")
store = HDTStore("./dbpedia2016-10.hdt.1")

# Display some metadata about the HDT document itself
print(f"Number of RDF triples: {len(store)}")
print(f"Number of subjects: {store.nb_subjects}")
print(f"Number of predicates: {store.nb_predicates}")
print(f"Number of objects: {store.nb_objects}")
print(f"Number of shared subject-object: {store.nb_shared}")

# Create an RDFlib Graph with the HDT document as a backend
graph = Graph(store=store)
# Out:
# Loading HDTStore at ...
# Number of RDF triples: 1137003322
# Number of subjects: 68940263
# Number of predicates: 123002
# Number of objects: 237607127
# Number of shared subject-object: 50711395

# %% [markdown]
# # Movielens1M
# ## Implemented Functions
#
# * check_mappings: marks the initial/generated mappings as potentially wrong
# * URI_generator: generates a list of potential URIs for each item.
# * find_correct: filter the list of potential URI names for each item, by the URI that seems to be a movie

# %%
import re
from tqdm import tqdm
from rdflib import Graph, URIRef, Namespace
from rdflib.namespace import RDFS, OWL, RDF

def check_mappings(movielens_mappings, graph):
  """ Mark the initial mappings as potentially wrong, if one of the following criteria holds:
      – the mapped entity seems to be wrong (the subject/abstract is not containing the year (range +1/-1) of publication, given in the name of the item)
      – the entity does not seem to be a movie, but e.g. the book the movie is based on (rdf:type does not contain SCHEMA.Movie or DBO.Film)
  Args:
      movielens_mappings (dict): Contains mappings for each item to its entity, provided by prior work.
      graph (Graph): RDFlib Graph with the HDT document as a backend.
  Returns:
      possibly_wrong_mappings (dict): Contains mappings for each item to its entity, if the mapped entity seems to be wrong.
  """
 
  SCHEMA = Namespace('http://schema.org/')
  DBO = Namespace('http://dbpedia.org/ontology/')
  DCT = Namespace("http://purl.org/dc/terms/")

  # Check for wrongly mapped entities
  possibly_wrong_mappings = {}
  for name, entity in tqdm(movielens_mappings.items()):

    # Step 1 – Check if subject/abstract is containing the year (range +1/-1) of publication
    year_name = re.findall(r'\(\d\d\d\d\)', name)[0][1:-1]
    year_name_range = [str(int(year_name)-1), year_name, str(int(year_name)+1)]
    year_subject_found = False
    is_contained = []
    for s, p, o in graph.triples((URIRef(entity), DCT.subject, None)):
      year_subject = re.findall(r'(\d\d\d\d)_films', o)
      if year_subject:
        year_subject = year_subject[0]
        year_subject_found = True
        year_subject_range = [str(int(year_subject)-1), year_subject, str(int(year_subject)+1)]
        is_contained = [i for i in year_name_range if i in year_subject_range]
        break
  
    if not year_subject_found:
      for s, p, o in graph.triples((URIRef(entity), DBO.abstract, None)):
        years_entity_abstract = re.findall(r'\d\d\d\d', o)
        is_contained = [i for i in year_name_range if i in years_entity_abstract]
        break

    if not is_contained:
      # print(f"'{name}': '{entity}' is possibly wrong because the subject and comment is not containing the year (range +1/-1) of publication.")
      possibly_wrong_mappings[name] = entity
      continue

    # Step 2 – Check if entity is a movie (rdf:type does contain SCHEMA.Movie or DBO.Film)
    is_movie = False
    for s, p, o in graph.triples((URIRef(entity), RDF.type, None)):
      if o == SCHEMA.Movie or o == DBO.Film:
        is_movie = True

    if not is_movie:
      # print(f"'{name}': '{entity}' is possibly wrong because it tends to be no movie.")
      possibly_wrong_mappings[name] = entity

  return possibly_wrong_mappings

def URI_generator(movielens_names):
    """ Generates a list of potential URIs for each item. 
        Potential URI names are based on personal experience, how correct URIs seems to look.
    Args: 
        movielens_names (list): Names of all items in the movielens dataset.
    Returns:
        URI_dict (dict): Contains mappings for each item to its list of potential URI names.
    """

    DBR = "http://dbpedia.org/resource/"

    URI_dict = {}
    for idx, name in enumerate(movielens_names):
        
        year_name = re.findall(r'\(\d\d\d\d\)', name)[0]
        second_name = re.findall(r'\(([^\)]+)\)', name)
        if len(second_name) >= 2:
          name = name.replace(second_name[0], "")
        
        # Resolve Mummy's Curse, The (1944) in The Mummy's Curse (1944)
        articles = [", The", ", An", ", A", ", El", ", Der", ", La", ", Les", ", L'", ", Le", ", O", ", Il"]
        for article in articles:
            if article in name:
                # Split Mummy's Curse, The (1944) in ["Mummy's Curse", 'The (1944)']
                name_split = name.split(", ")
                # Create correct name
                if article == ", L'":
                  name = article.split(", ")[1] + " ".join([name_split[0], year_name])
                else:
                  name = " ".join([article.split(", ")[1], name_split[0], year_name])
                break
        
        # Create URI form of the Name
        year_name = re.findall(r'\(\d\d\d\d\)', name)[0][1:-1]

        name = name.replace("?", "%3F")
        uriname = name.replace(" ", "_")
        
        base = DBR + uriname.split("_(", 1)[0]
        film = base + "_(film)"

        year = int(year_name)
        year_film_1= base + f"_({year-1}_film)"
        year_film_2= base + f"_({year}_film)"
        year_film_3= base + f"_({year+1}_film)"
        
        URI_dict[movielens_names[idx]] = [year_film_1, year_film_2, year_film_3, film, base]

        if second_name:
          second_name = second_name[0]
          if not second_name.isdigit():
            articles = [", The", ", An", ", A", ", El", ", Der", ", La", ", Les", ", L'", ", Le", ", O", ", Il"]
            for article in articles:
              if article in second_name:
                  # Split Mummy's Curse, The (1944) in ["Mummy's Curse", 'The (1944)']
                  name_split = second_name.split(", ")
                  year_name_str = "("+year_name+")"
                  # Create correct name
                  if article == ", L'":
                    second_name = article.split(", ")[1] + name_split[0]
                  else:
                    second_name = " ".join([article.split(", ")[1], name_split[0]])
                  break

            second_name = second_name.replace("?", "%3F")
            second_name_uriname = second_name.replace(" ", "_")

            base = DBR + second_name_uriname.rsplit("_(", 1)[0]
            film = base + "_(film)"

            year = int(year_name)
            year_film_1= base + f"_({year-1}_film)"
            year_film_2= base + f"_({year}_film)"
            year_film_3= base + f"_({year+1}_film)"

            URI_dict[movielens_names[idx]].append(year_film_1)
            URI_dict[movielens_names[idx]].append(year_film_2)
            URI_dict[movielens_names[idx]].append(year_film_3)
            URI_dict[movielens_names[idx]].append(film)
            URI_dict[movielens_names[idx]].append(base)

        if "(" in base:
          uriname = name.replace(" ", "_")

          base = DBR + uriname.rsplit("_(", 2)[0]
          film = base + "_(film)"

          year = int(year_name)
          year_film_1= base + f"_({year-1}_film)"
          year_film_2= base + f"_({year}_film)"
          year_film_3= base + f"_({year+1}_film)"

          URI_dict[movielens_names[idx]].append(year_film_1)
          URI_dict[movielens_names[idx]].append(year_film_2)
          URI_dict[movielens_names[idx]].append(year_film_3)
          URI_dict[movielens_names[idx]].append(film)
          URI_dict[movielens_names[idx]].append(base)

        if ": " in name:
          uriname = name.replace(" ", "_")

          base = DBR + uriname.split(":_")[0]
          film = base + "_(film)"

          year = int(year_name)
          year_film_1= base + f"_({year-1}_film)"
          year_film_2= base + f"_({year}_film)"
          year_film_3= base + f"_({year+1}_film)"

          URI_dict[movielens_names[idx]].append(year_film_1)
          URI_dict[movielens_names[idx]].append(year_film_2)
          URI_dict[movielens_names[idx]].append(year_film_3)
          URI_dict[movielens_names[idx]].append(film)
          URI_dict[movielens_names[idx]].append(base)

        if "%3F" in name:
          uriname = name.replace(" ", "_")
          uriname = uriname.replace("%3F", "")

          base = DBR + uriname.rsplit("_(", 1)[0]
          film = base + "_(film)"

          year = int(year_name)
          year_film_1= base + f"_({year-1}_film)"
          year_film_2= base + f"_({year}_film)"
          year_film_3= base + f"_({year+1}_film)"

          URI_dict[movielens_names[idx]].append(year_film_1)
          URI_dict[movielens_names[idx]].append(year_film_2)
          URI_dict[movielens_names[idx]].append(year_film_3)
          URI_dict[movielens_names[idx]].append(film)
          URI_dict[movielens_names[idx]].append(base)
        
    return URI_dict

def find_correct(URI_dict, graph):
  """ Filter the list of potential URI names for each item, by the URI that seems to be a movie (rdf:type does contain SCHEMA.Movie or DBO.Film)
      Note that we here don't have to check anymore for the year constraint, as we take care of that by the generated URIs.
      We could be more exact here, but we tend to do almost 100% alright with the current procedure.
  Args: 
      URI_dict (dict): Contains mappings for each item to its list of potential URI names.
      graph (Graph): RDFlib Graph with the HDT document as a backend.
  Returns:
      correct_URIs (dict): Contains mappings for each item to its potential URI, maps item to -1 otherwise.
  """

  SCHEMA = Namespace('http://schema.org/')
  DBO = Namespace('http://dbpedia.org/ontology/')

  correct_URIs = {}
  for name, URI_list in tqdm(URI_dict.items()):
    correct_URIs[name] = -1

    for entity in URI_list:

        # Step 1 – Handle Disambiguation Page
        # Check, if one of the objects listed is a movie (rdf:type does contain SCHEMA.Movie or DBO.Film)
        pageRedirects = set()
        for s, p, o in graph.triples((URIRef(entity), DBO.wikiPageRedirects, None)):
            pageRedirects.add(o)

        rp_movie = False
        for rp in pageRedirects:
          for s, p, o in graph.triples((URIRef(rp), None, None)):
            if p == RDF.type:
              if o == SCHEMA.Movie or o == DBO.Film:
                rp_movie = True

        if rp_movie:
          correct_URIs[name] = str(rp)
          break

        # Step 2 – Check if the entity is a movie (rdf:type does contain SCHEMA.Movie or DBO.Film)
        movie = False
        for s, p, o in graph.triples((URIRef(entity), None, None)):
          if p == RDF.type:
            if o == SCHEMA.Movie or o == DBO.Film:
              movie = True
              break
        
        if movie:
          correct_URIs[name] = entity
          break

  return correct_URIs

# %% [markdown]
# ## Get URIs

# %%
import pandas as pd

# Load data
movielens_df = pd.read_csv('./movielens/MappingMovielens2DBpedia-1.2.tsv', sep='\t', header=None, engine='python')
movielens_df.columns = ['ID', 'Movie', 'URI']
movielens_ids = list(movielens_df['ID'])
movielens_names = list(movielens_df['Movie'])
movielens_entities = list(movielens_df['URI'])

# Create dict that contains mappings for each item to its entity, provided by prior work.
movielens_mappings = pd.Series(movielens_df.URI.values,index=movielens_df.Movie).to_dict()

# %% [markdown]
# ## Control URIs

# %%
# Get dict that contains mappings for each item to its entity, if the mapped entity seems to be wrong.
possibly_wrong_mappings = check_mappings(movielens_mappings, graph)
print(len(possibly_wrong_mappings))
# Out:
# 100%|██████████| 3301/3301 [00:00<00:00, 6746.43it/s]
# 405

# %% [markdown]
# ## Get Correct URIs

# %%
# Generates a list of potential URIs for each item.
URI_dict = URI_generator(movielens_names)

# Filter the list of potential URI names for each item, by the URI that seems to be a movie (rdf:type does contain SCHEMA.Movie or DBO.Film)
correct_URIs = find_correct(URI_dict, graph)
# Out:
# 100%|██████████| 3301/3301 [00:06<00:00, 517.60it/s]

# %%
# Seperate correct_URIs in two dicts:

# 1. not_found_URIs contains all the mappings of items, no potential correct URI could be found for
not_found_URIs = {key:value for (key,value) in correct_URIs.items() if value == -1}
print(len(not_found_URIs))

# 2. found_URIs contains all the mappings of items, a potential correct URI could be found for successfully
found_URIs = {key:value for (key,value) in correct_URIs.items() if value != -1}
print(len(found_URIs))
# Out:
# 83
# 3218

# %%
# Check, which of the found_URIs mappings could still be wrong.
possibly_wrong_found_URIs = check_mappings(found_URIs, graph)
print(len(possibly_wrong_found_URIs))
# Out:
# 100%|██████████| 3218/3218 [00:00<00:00, 6990.10it/s]
# 27

# %% [markdown]
# ## Make Corrections

# %%
print(len(possibly_wrong_mappings), "of the initial URIs are possibly wrong.")

not_found_intersection = [i for i in possibly_wrong_mappings.keys() if i in not_found_URIs.keys()]
print("Possibly wrong URIs that can't be corrected because no URI could be found:", len(not_found_intersection))

found_double_possible_wrong_intersection = [i for i in possibly_wrong_mappings.keys() if i in possibly_wrong_found_URIs.keys()]
print("Possibly wrong can't be corrected beacuse found URI is also possibly wrong:", len(found_double_possible_wrong_intersection))

found_intersection = [i for i in possibly_wrong_mappings.keys() if i in found_URIs.keys() and i not in possibly_wrong_found_URIs.keys()]
print("Possibly wrong can be corrected, because found URI seems to be valid:", len(found_intersection))
# Out:
# 405 of the initial URIs are possibly wrong.
# Possibly wrong URIs that can't be corrected because no URI could be found: 37
# Possibly wrong can't be corrected beacuse found URI is also possibly wrong: 18
# Possibly wrong can be corrected, because found URI seems to be valid: 350

# %%
# Update wrong URIs with found valid URIs
count = 0
for key in found_intersection:
  if possibly_wrong_mappings[key] != found_URIs[key]:
    index = movielens_df.loc[movielens_df['Movie'] == key].index
    movielens_df.at[index, 'URI'] = found_URIs[key]
    count += 1
    print(f"{key:<45} {possibly_wrong_mappings[key]:<70} \t
# Taxi Driver (1976)                            http://dbpedia.org/resource/Taxi_Driver_(1954_film)                    	 http://dbpedia.org/resource/Taxi_Driver
# Fall (1997)                                   http://dbpedia.org/resource/Intolerance_(film)                         	 http://dbpedia.org/resource/Fall_(1997_film)
# In Crowd, The (2000)                          http://dbpedia.org/resource/The_In_Crowd                               	 http://dbpedia.org/resource/The_In_Crowd_(2000_film)
# What Ever Happened to Baby Jane? (1962)       http://dbpedia.org/resource/What_Ever_Happened_to_Baby_Jane%253F_(1962_film) 	 http://dbpedia.org/resource/What_Ever_Happened_to_Baby_Jane%3F_(1962_film)
# Class (1983)                                  http://dbpedia.org/resource/A_Touch_of_Class_(film)                    	 http://dbpedia.org/resource/Class_(film)
# Updated 350 URIs

# %%
# Delete wrong URIs, where a URI is found but the found URI seems to also be possibly wrong
for key in found_double_possible_wrong_intersection:
    index = movielens_df.loc[movielens_df['Movie'] == key].index
    movielens_df = movielens_df.drop(index)
    print(f"{key:<45} {possibly_wrong_mappings[key]:<70} \t {possibly_wrong_found_URIs[key]:<45}")
# Out:
# Acid House, The (1998)                        http://dbpedia.org/resource/The_Acid_House_(film)                      	 http://dbpedia.org/resource/The_Acid_House_(film)
# Solar Crisis (1993)                           http://dbpedia.org/resource/Solar_Crisis_(film)                        	 http://dbpedia.org/resource/Solar_Crisis_(film)
# Breathing Room (1996)                         http://dbpedia.org/resource/Breathing_Room                             	 http://dbpedia.org/resource/Breathing_Room
# Century of Cinema, A (1994)                   http://dbpedia.org/resource/A_Century_of_Cinema                        	 http://dbpedia.org/resource/A_Century_of_Cinema
# Choices (1981)                                http://dbpedia.org/resource/Choices_(film)                             	 http://dbpedia.org/resource/Choices_(film)
# Full Speed (1996)                             http://dbpedia.org/resource/Full_Speed                                 	 http://dbpedia.org/resource/Full_Speed
# Empty Mirror, The (1999)                      http://dbpedia.org/resource/The_Empty_Mirror                           	 http://dbpedia.org/resource/The_Empty_Mirror
# Tainted (1998)                                http://dbpedia.org/resource/Tainted                                    	 http://dbpedia.org/resource/Tainted
# I Married A Strange Person (1997)             http://dbpedia.org/resource/I_Married_a_Strange_Person!                	 http://dbpedia.org/resource/I_Married_a_Strange_Person!
# Little Nemo: Adventures in Slumberland (1992) http://dbpedia.org/resource/Little_Nemo:_Adventures_in_Slumberland     	 http://dbpedia.org/resource/Little_Nemo:_Adventures_in_Slumberland
# Sleepover (1995)                              http://dbpedia.org/resource/Sleepover_(film)                           	 http://dbpedia.org/resource/Sleepover_(film)
# Tarantella (1995)                             http://dbpedia.org/resource/Tarantella_(film)                          	 http://dbpedia.org/resource/Tarantella_(film)
# Henry: Portrait of a Serial Killer (1990)     http://dbpedia.org/resource/Henry:_Portrait_of_a_Serial_Killer         	 http://dbpedia.org/resource/Henry:_Portrait_of_a_Serial_Killer
# It Happened Here (1961)                       http://dbpedia.org/resource/It_Happened_Here                           	 http://dbpedia.org/resource/It_Happened_Here
# Get Over It (1996)                            http://dbpedia.org/resource/Get_Over_It_(film)                         	 http://dbpedia.org/resource/Get_Over_It_(film)
# Criminals (1996)                              http://dbpedia.org/resource/Criminals_Gone_Wild                        	 http://dbpedia.org/resource/Criminals_(film)
# Hearts and Minds (1996)                       http://dbpedia.org/resource/Hearts_and_Minds_(film)                    	 http://dbpedia.org/resource/Hearts_and_Minds_(film)
# Machine, The (1994)                           http://dbpedia.org/resource/The_Time_Machine_(1960_film)               	 http://dbpedia.org/resource/The_Machine_(film)

# %%
# Delete wrong URIs, where no other URI could be found
for key in not_found_intersection:
    index = movielens_df.loc[movielens_df['Movie'] == key].index
    movielens_df = movielens_df.drop(index)
    print(f"{key:<45} {possibly_wrong_mappings[key]:<70} \t {not_found_URIs[key]:<45}")
# Out:
# Boys of St. Vincent, The (1993)               http://dbpedia.org/resource/The_Boys_of_St._Vincent                    	 -1
# Last Resort (1994)                            http://dbpedia.org/resource/Last_Resort_(1986_film)                    	 -1
# Blood & Wine (1997)                           http://dbpedia.org/resource/Blood_Diamond_(film)                       	 -1
# Contact (1997)                                http://dbpedia.org/resource/Contact                                    	 -1
# Emma (1996)                                   http://dbpedia.org/resource/Emma                                       	 -1
# Homage (1995)                                 http://dbpedia.org/resource/Homage_to_Chagall:_The_Colours_of_Love     	 -1
# Eden (1997)                                   http://dbpedia.org/resource/Eden_Lake                                  	 -1
# Open Season (1996)                            http://dbpedia.org/resource/Open_Season                                	 -1
# Soldier (1998)                                http://dbpedia.org/resource/Soldier_of_Orange                          	 -1
# Last September, The (1999)                    http://dbpedia.org/resource/The_Last_September__The_Last_September__1  	 -1
# Vacation (1983)                               http://dbpedia.org/resource/RV_(film)                                  	 -1
# Fausto (1993)                                 http://dbpedia.org/resource/El_Fausto_criollo                          	 -1
# Kaspar Hauser (1993)                          http://dbpedia.org/resource/The_Enigma_of_Kaspar_Hauser                	 -1
# Harvest (1998)                                http://dbpedia.org/resource/Harvest_of_Shame                           	 -1
# Harlem (1993)                                 http://dbpedia.org/resource/Harlem_Nights                              	 -1
# Back Stage (2000)                             http://dbpedia.org/resource/Back_Stage_(1923_film)                     	 -1
# Madame Butterfly (1995)                       http://dbpedia.org/resource/Madame_Butterfly_(1915_film)               	 -1
# Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995) http://dbpedia.org/resource/The_Englishman_Who_Went_Up_a_Hill_But_Came_Down_a_Mountain 	 -1
# Wonderland (1997)                             http://dbpedia.org/resource/Wonderland_(2003_film)                     	 -1
# Floating (1997)                               http://dbpedia.org/resource/Floating_Weeds                             	 -1
# Chushingura (1962)                            http://dbpedia.org/resource/Ch%25C5%25ABshingura:_Hana_no_Maki,_Yuki_no_Maki 	 -1
# James Dean Story, The (1957)                  http://dbpedia.org/resource/The_James_Dean_Story                       	 -1
# Asylum (1972)                                 http://dbpedia.org/resource/Asylum                                     	 -1
# Knockout (1999)                               http://dbpedia.org/resource/Knockout_(2011_film)                       	 -1
# Spanish Fly (1998)                            http://dbpedia.org/resource/Spanish_Fly_(1975_film)                    	 -1
# And the Band Played On (1993)                 http://dbpedia.org/resource/And_the_Band_Played_On_(film)              	 -1
# Grateful Dead (1995)                          http://dbpedia.org/resource/Grateful_Dead:_So_Far                      	 -1
# Alley Cats, The (1968)                        http://dbpedia.org/resource/Alley_Cats_Strike                          	 -1
# Loaded (1994)                                 http://dbpedia.org/resource/Loaded_Pistols                             	 -1
# To Have, or Not (1995)                        http://dbpedia.org/resource/Deep_Throat_(film)                         	 -1
# Bliss (1997)                                  http://dbpedia.org/resource/Bliss_(1985_film)                          	 -1
# Squeeze (1996)                                http://dbpedia.org/resource/Squeeze_Play!                              	 -1
# Farmer & Chase (1995)                         http://dbpedia.org/resource/Oyster_Farmer                              	 -1
# Quatermass II (1957)                          http://dbpedia.org/resource/Quatermass_II__Quatermass_II__1            	 -1
# Castle, The (1997)                            http://dbpedia.org/resource/The_Castle                                 	 -1
# East is East (1999)                           http://dbpedia.org/resource/East_Is_East_(film)                        	 -1
# MURDER and murder (1996)                      http://dbpedia.org/resource/Murder_Me,_Murder_You                      	 -1

# %%
# Check if duplicates exist
movielens_df[movielens_df.duplicated(['URI'], keep=False)]
# Out:
#         ID                                        Movie  \
# 1272  3065                             Ten Benny (1997)
# 1487   811                     Bewegte Mann, Der (1994)
# 1717   860  Maybe, Maybe Not (Bewegte Mann, Der) (1994)
# 2386   875                       Nothing to Lose (1994)
#
#                                                URI
# 1272         http://dbpedia.org/resource/Ten_Benny
# 1487  http://dbpedia.org/resource/Der_bewegte_Mann
# 1717  http://dbpedia.org/resource/Der_bewegte_Mann
# 2386         http://dbpedia.org/resource/Ten_Benny

# %%
movielens_df.shape
# Out:
# (3246, 3)

# %%
# Delete Duplicates but keep first element, otherwise, we will have Problems with Index Mappings in the function later
movielens_df.drop_duplicates(subset ="URI", keep = 'first', inplace = True)

# %%
movielens_df.shape
# Out:
# (3244, 3)

# %% [markdown]
# ## Make the Update

# %%
movielens_df.to_csv('./movielens/Mapping2DBpedia-1.2-corrected.tsv', sep='\t', index = False, header = False, encoding="utf-8")

# %% [markdown]
# # Lastfm
# ## Implemented Functions
#
# * check_mappings: marks initial/generated mappings as potentially wrong
# * URI_generator: generates a list of potential URIs for each item.
# * find_correct: filter the list of potential URI names for each item, by the URI that seems to be a artist

# %%
import re
from tqdm import tqdm
from rdflib import Graph, URIRef, Namespace
from rdflib.namespace import RDFS, OWL, RDF

def check_mappings(lastfm_mappings, graph):
    """ Mark the mapped entity as potentially wrong, if one of the following criteria holds:
      – the mapped entity seems to be wrong (the abstract is empty or the name does not match).
      – the entity does not seem to be an artist (rdf:type does not contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)
    Args:
        lastfm_mappings (dict): Contains mappings for each item to its entity, provided by prior work.
        graph (Graph): RDFlib Graph with the HDT document as a backend.
    Returns:
        possibly_wrong_mappings (dict): Contains mappings for each item to its entity, if the mapped entity seems to be wrong.
    """

    SCHEMA = Namespace('http://schema.org/')
    DBR = "http://dbpedia.org/resource/"
    DBO = Namespace('http://dbpedia.org/ontology/')
    DCT = Namespace("http://purl.org/dc/terms/") 

    # Check for wrongly mapped entities
    possibly_wrong_mappings = {}
    different_name = {}
    for name, entity in tqdm(lastfm_mappings.items()):

        # Step 1 – Check if abstract is not empty and the names match
        is_not_empty = False
        for s, p, o in graph.triples((URIRef(entity), DBO.abstract, None)):
          is_not_empty = True
    
        if not is_not_empty:
          #print(f"'{name}': '{entity}' is possibly wrong because empty.")
          possibly_wrong_mappings[name] = entity
          continue

        uriname = name.replace(" ", "_")
        base = DBR + uriname
        entity_cleaned = entity

        if entity[-1] == ")":
            splitted_list = entity.split("(")[0]
            entity_cleaned = splitted_list[:-1]

        if entity_cleaned.lower() != base.lower():
            #print(f"'{name}': '{entity}' is possibly wrong because different name.")
            possibly_wrong_mappings[name] = entity
            continue
        
        # Step 2 – Check if entity is a artist (rdf:type does contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)
        is_artist = False
        for s, p, o in graph.triples((URIRef(entity), RDF.type, None)):
          if o == DBO.MusicalArtist or o == DBO.Band or o == SCHEMA.MusicGroup or o == DBO.Artist:
            is_artist = True

        if not is_artist:
          #print(f"'{name}': '{entity}' is possibly wrong because it tends to be no artist.")
          possibly_wrong_mappings[name] = entity
  
    return possibly_wrong_mappings

def URI_generator(lastfm_names):
    """ Generates a list of potential URIs for each item. 
        Potential URI names are based on personal experience, how correct URIs seems to look.
    Args: 
        lastfm_names (list): Names of all items in the movielens dataset.
    Returns:
        URI_dict (dict): Contains mappings for each item to its list of potential URI names.
    """
    DBR = "http://dbpedia.org/resource/"

    URI_dict = {}
    for idx, name in enumerate(lastfm_names):
        
        uriname = name.replace(" ", "_")
        
        base = DBR + uriname
        band = base + "_(band)"
        musician = base + "_(musician)"
        singer = base + "_(singer)"
        
        URI_dict[lastfm_names[idx]] = [band, musician, singer, base]
        
    return URI_dict

def find_correct(URI_dict, graph):
  """ Filter the list of potential URI names for each item, by the URI that seems to be an artist (rdf:type does not contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)
      Note that we here don't have to check anymore for the year constraint, as we take care of that by the generated URIs.
      We could be more exact here, but we tend to do almost 100% alright with the current procedure.
  Args: 
      URI_dict (dict): Contains mappings for each item to its list of potential URI names.
  Returns:
      correct_URIs (dict): Contains mappings for each item to its potential URI, maps item to -1 otherwise.
  """

  SCHEMA = Namespace('http://schema.org/')
  DBO = Namespace('http://dbpedia.org/ontology/')

  correct_URIs = {}
  for name, URI_list in tqdm(URI_dict.items()):
    correct_URIs[name] = -1

    for entity in URI_list:

        # Step 1 – Handle Disambiguation Page
        # Check, if one of the objects listed is an artist (rdf:type does not contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)
        pageRedirects = set()
        for s, p, o in graph.triples((URIRef(entity), DBO.wikiPageRedirects, None)):
          pageRedirects.add(o)

        rp_artist = False
        for rp in pageRedirects:
          for s, p, o in graph.triples((URIRef(rp), RDF.type, None)):
            if o == DBO.MusicalArtist or o == DBO.Band or o == SCHEMA.MusicGroup or o == DBO.Artist:
              rp_artist = True

        if rp_artist:
          correct_URIs[name] = str(rp)
          break

        # Step 2 – Check if the entity is an artist (rdf:type does not contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)
        artist = False
        for s, p, o in graph.triples((URIRef(entity), RDF.type, None)):
          if p == RDF.type:
            if o == DBO.MusicalArtist or o == DBO.Band or o == SCHEMA.MusicGroup or o == DBO.Artist:
              artist = True
              break
        
        if artist:
          correct_URIs[name] = entity
          break

  return correct_URIs

# %% [markdown]
# ## Get URIs

# %%
import pandas as pd

# Load data
lastfm_df = pd.read_csv('./lastfm/MappingLastfm2DBpedia-1.2.tsv', sep='\t', header=None, engine='python')
lastfm_df.columns = ['ID', 'Artist', 'URI']
lastfm_ids = list(lastfm_df['ID'])
lastfm_names = list(lastfm_df['Artist'])
lastfm_entities = list(lastfm_df['URI'])

# Create dict that contains mappings for each item to its entity, provided by prior work.
lastfm_dict = pd.Series(lastfm_df.URI.values,index=lastfm_df.Artist).to_dict()

# %% [markdown]
# ## Analyze URIs
# First we analyze the initial URIs to get well working conditions for the "check"-function.<br>
# We have to do this, as the criteria is not as obvious as it was for the movielens dataset.<br>
#
# Based on the following output, we define the criteria as:<br>
# _entity is a artist (rdf:type does contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)_

# %%
import re
from tqdm import tqdm
from rdflib import Graph, URIRef, Namespace
from rdflib.namespace import RDFS, OWL, RDF

def analyze_entitities(entities):
  """ Return Frequency dict of tags (content in paranthesis) of the inial DBPedia URIs
  Args:
      lastfm_entities (list): Intial URIs of the lastfm dataset.
  Returns:
      tag_dict (dict): Maps each tag to its occurence frequency.
  """

  tag_dict = {}
  for enitity in lastfm_entities:
    name_extra = re.findall('\(.*?\)', enitity)
    if name_extra:
      entitiy_name = name_extra[0]
      tag_dict[entitiy_name] = tag_dict.get(entitiy_name, 0) + 1

  return tag_dict

def analyze_tags(lastfm_entities, graph):
  """ Return Frequency dict of found rdf.types of the inial DBPedia URIs
  Args:
      lastfm_entities (list): Intial URIs of the lastfm dataset.
      graph (Graph): RDFlib Graph with the HDT document as a backend.
  Returns:
      type_dict (dict): Maps each rdf.type to its occurence frequency.
  """

  type_dict = {}
  for entity in tqdm(lastfm_entities):
    for s, p, o in graph.triples((URIRef(entity), RDF.type, None)):
      type_dict[o] = type_dict.get(o, 0) + 1

  return type_dict

# %%
# Get frequency dict of tags (content in paranthesis) of the inial DBPedia URIs
name_dict = analyze_entitities(lastfm_entities)
for w in sorted(name_dict, key=name_dict.get, reverse=True):
  if name_dict[w] > 10:
    print(w, name_dict[w])
# Out:
# (band) 1388
# (musician) 181
# (singer) 137
# (rapper) 54
# (group) 32
# (American_band) 18
# (British_band) 14
# (composer) 11

# %%
# Get frequency dict of found rdf.types of the inial DBPedia URIs
tags_dict = analyze_tags(lastfm_entities, store)
for w in sorted(tags_dict, key=tags_dict.get, reverse=True):
  if tags_dict[w] > 500:
    print(w, tags_dict[w])
# Out:
# 100%|██████████| 10180/10180 [00:04<00:00, 2037.04it/s]
# http://www.w3.org/2002/07/owl#Thing 9844
# http://dbpedia.org/ontology/Agent 9810
# http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent 9807
# http://www.wikidata.org/entity/Q24229398 9807
# http://schema.org/MusicGroup 9420
# http://dbpedia.org/ontology/Band 6448
# http://dbpedia.org/ontology/Organisation 5957
# http://schema.org/Organization 5954
# http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#SocialPerson 5954
# http://www.wikidata.org/entity/Q43229 5954
# http://dbpedia.org/ontology/Group 5953
# http://www.wikidata.org/entity/Q215380 5952
# http://dbpedia.org/ontology/MusicalArtist 4547
# http://dbpedia.org/ontology/Person 4028
# http://schema.org/Person 3853
# http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson 3853
# http://www.wikidata.org/entity/Q215627 3853
# http://www.wikidata.org/entity/Q5 3853
# http://xmlns.com/foaf/0.1/Person 3853
# http://dbpedia.org/ontology/Artist 3468
# http://www.wikidata.org/entity/Q483501 3468
# http://umbel.org/umbel/rc/Band_MusicGroup 2076
# http://umbel.org/umbel/rc/MusicalPerformer 1750
# http://umbel.org/umbel/rc/Artist 932
# http://www.w3.org/2004/02/skos/core#Concept 858
# http://umbel.org/umbel/rc/Organization 594

# %% [markdown]
# ## Control URIs

# %%
# Get dict that contains mappings for each item to its entity, if the mapped entity seems to be wrong.
possibly_wrong_mappings = check_mappings(lastfm_dict, graph)
print(len(possibly_wrong_mappings))
# Out:
# 100%|██████████| 10180/10180 [00:02<00:00, 4312.30it/s]
# 1676

# %% [markdown]
# ## Get Correct URIs

# %%
# Generates a list of potential URIs for each item.
URI_dict = URI_generator(lastfm_names)

# Filter the list of potential URI names for each item, by the URI that seems to be an artist (rdf:type does not contain DBO.MusicalArtist or DBO.Band or SCHEMA.MusicGroup or DBO.Artist)
correct_URIs = find_correct(URI_dict, graph)
# Out:
# 100%|██████████| 10180/10180 [00:02<00:00, 4996.21it/s]

# %%
# Seperate correct_URIs in two dicts:

# 1. not_found_URIs contains all the mappings of items, no potential correct URI could be found for
not_found_URIs = {key:value for (key,value) in correct_URIs.items() if value == -1}
print(len(not_found_URIs))

# 2. found_URIs contains all the mappings of items, a potential correct URI could be found for successfully
found_URIs = { key:value for (key,value) in correct_URIs.items() if value != -1}
print(len(found_URIs))
# Out:
# 1115
# 9065

# %%
# Check, which of the found_URIs mappings could still be wrong.
possibly_wrong_found_URIs = check_mappings(found_URIs, graph)
print(len(possibly_wrong_found_URIs))
# Out:
# 100%|██████████| 9065/9065 [00:02<00:00, 4157.52it/s]
# 599

# %% [markdown]
# ## Make Corrections

# %%
print(len(possibly_wrong_mappings), "URIs are possibly wrong.")

not_found_intersection = [i for i in possibly_wrong_mappings.keys() if i in not_found_URIs.keys()]
print("Possibly wrong URIs that can't be corrected because no URI could be found:", len(not_found_intersection))

found_double_possible_wrong_intersection = [i for i in possibly_wrong_mappings.keys() if i in possibly_wrong_found_URIs.keys()]
print("Possibly wrong can't be corrected beacuse found URI is also possibly wrong:", len(found_double_possible_wrong_intersection))

found_intersection = [i for i in possibly_wrong_mappings.keys() if i in found_URIs.keys() and i not in possibly_wrong_found_URIs.keys()]
print("Possibly wrong can be corrected, because found URI seems to be valid:", len(found_intersection))
# Out:
# 1676 URIs are possibly wrong.
# Possibly wrong URIs that can't be corrected because no URI could be found: 824
# Possibly wrong can't be corrected beacuse found URI is also possibly wrong: 566
# Possibly wrong can be corrected, because found URI seems to be valid: 286

# %%
# Update Found Artist
count = 0
for key in found_intersection:
  if possibly_wrong_mappings[key] != found_URIs[key]:
    # Update df accordingly to found_URI
    index = lastfm_df.loc[lastfm_df['Artist'] == key].index
    lastfm_df.at[index, 'URI'] = found_URIs[key]
    count += 1
    print(f"{key:<45} {possibly_wrong_mappings[key]:<70} \t
# Usher                                         http://dbpedia.org/resource/Usher_(entertainer)                        	 http://dbpedia.org/resource/Usher_(singer)
# DQ                                            http://dbpedia.org/resource/The_Animal_Crackers_(band)                 	 http://dbpedia.org/resource/DQ_(singer)
# Giuseppe Verdi                                http://dbpedia.org/resource/Orchestra_Sinfonica_di_Milano_Giuseppe_Verdi 	 http://dbpedia.org/resource/Giuseppe_Verdi
# Rhianna                                       http://dbpedia.org/resource/Rhianna                                    	 http://dbpedia.org/resource/Rhianna_(singer)
# The Go! Team                                  http://dbpedia.org/resource/The_Go!_Team_(UK_band)                     	 http://dbpedia.org/resource/The_Go!_Team
# My Little Airport                             http://dbpedia.org/resource/My_little_airport                          	 http://dbpedia.org/resource/My_Little_Airport
# Phoenix                                       http://dbpedia.org/resource/Transsylvania_Phoenix                      	 http://dbpedia.org/resource/Phoenix_(band)
# Flyleaf                                       http://dbpedia.org/resource/Flyleaf                                    	 http://dbpedia.org/resource/Flyleaf_(band)
# Aerosmith                                     http://dbpedia.org/resource/List_of_Aerosmith_band_members             	 http://dbpedia.org/resource/Aerosmith
# Angels & Airwaves                             http://dbpedia.org/resource/Angels_of_Light                            	 http://dbpedia.org/resource/Angels_&_Airwaves
# Techno Animal                                 http://dbpedia.org/resource/Kevin_Martin_(British_musician)            	 http://dbpedia.org/resource/Techno_Animal
# Faith No More                                 http://dbpedia.org/resource/List_of_Faith_No_More_band_members         	 http://dbpedia.org/resource/Faith_No_More
# The Immortals                                 http://dbpedia.org/resource/Brand_New_Immortals                        	 http://dbpedia.org/resource/The_Immortals_(band)
# Lunatic Soul                                  http://dbpedia.org/resource/Mariusz_Duda                               	 http://dbpedia.org/resource/Lunatic_Soul
# Ray Charles                                   http://dbpedia.org/resource/Ray_Charles_(composer)                     	 http://dbpedia.org/resource/Ray_Charles
# Updated 286 URIs

# %%
# Delete Wrong Found Artist
for key in found_double_possible_wrong_intersection:
    index = lastfm_df.loc[lastfm_df['Artist'] == key].index
    lastfm_df = lastfm_df.drop(index)
    print(f"{key:<45} {possibly_wrong_mappings[key]:<70} \t {possibly_wrong_found_URIs[key]:<45}")# Delete Wrong Found Movies
# Out:
# Twin Sister                                   http://dbpedia.org/resource/Mr._Twin_Sister                            	 http://dbpedia.org/resource/Mr_Twin_Sister
# UK Subs                                       http://dbpedia.org/resource/U.K._Subs                                  	 http://dbpedia.org/resource/U.K._Subs
# Thao with The Get Down Stay Down              http://dbpedia.org/resource/Thao_&_The_Get_Down_Stay_Down              	 http://dbpedia.org/resource/Thao_&_the_Get_Down_Stay_Down
# The Bug                                       http://dbpedia.org/resource/Luv_Bug                                    	 http://dbpedia.org/resource/Kevin_Martin_(British_musician)
# There For Tomorrow                            http://dbpedia.org/resource/There_for_Tomorrow                         	 http://dbpedia.org/resource/Afterhour_(band)
# Reverend Horton Heat                          http://dbpedia.org/resource/The_Reverend_Horton_Heat                   	 http://dbpedia.org/resource/The_Reverend_Horton_Heat
# Reeves & Mortimer                             http://dbpedia.org/resource/Reeves_Gabrels                             	 http://dbpedia.org/resource/Vic_and_Bob
# Utada                                         http://dbpedia.org/resource/Hikaru_Utada                               	 http://dbpedia.org/resource/Utada_Hikaru
# Agnes                                         http://dbpedia.org/resource/Dave_Douglas_(drummer)                     	 http://dbpedia.org/resource/Dave_Douglas_(drummer)
# Tommy february6                               http://dbpedia.org/resource/Tomoko_Kawase                              	 http://dbpedia.org/resource/Tomoko_Kawase
# The Morning Benders                           http://dbpedia.org/resource/POP_ETC                                    	 http://dbpedia.org/resource/POP_ETC
# Devon Allman's Honeytribe                     http://dbpedia.org/resource/Honeytribe                                 	 http://dbpedia.org/resource/Honeytribe
# Chicas                                        http://dbpedia.org/resource/Tres_Chicas                                	 http://dbpedia.org/resource/Chicas
# Bumblefoot                                    http://dbpedia.org/resource/Ron_%22Bumblefoot%22_Thal                  	 http://dbpedia.org/resource/Ron_%22Bumblefoot%22_Thal
# Trading Yesterday                             http://dbpedia.org/resource/The_Age_of_Information                     	 http://dbpedia.org/resource/The_Age_of_Information
# Tarja                                         http://dbpedia.org/resource/Tarja_Turunen                              	 http://dbpedia.org/resource/Tarja_Turunen
# Alice Nine                                    http://dbpedia.org/resource/Alice_Nine                                 	 http://dbpedia.org/resource/A9_(band)
# P. Diddy                                      http://dbpedia.org/resource/Sean_Combs                                 	 http://dbpedia.org/resource/Sean_Combs
# Chibi                                         http://dbpedia.org/resource/The_Birthday_Massacre                      	 http://dbpedia.org/resource/The_Birthday_Massacre
# Lil' Wayne                                    http://dbpedia.org/resource/Lil_Wayne                                  	 http://dbpedia.org/resource/Lil_Wayne
# Big Punisher                                  http://dbpedia.org/resource/Big_Pun                                    	 http://dbpedia.org/resource/Big_Pun
# Ola                                           http://dbpedia.org/resource/Pay*Ola                                    	 http://dbpedia.org/resource/Ola_Svensson
# ATC                                           http://dbpedia.org/resource/A_Touch_of_Class_(band)                    	 http://dbpedia.org/resource/A_Touch_of_Class_(band)
# Devin Townsend Project                        http://dbpedia.org/resource/Devin_Townsend                             	 http://dbpedia.org/resource/Devin_Townsend
# The Devin Townsend Band                       http://dbpedia.org/resource/Devin_Townsend                             	 http://dbpedia.org/resource/Devin_Townsend
# The Pretty Things                             http://dbpedia.org/resource/The_Pretty_Things                          	 http://dbpedia.org/resource/Pretty_Things

# %%
for key in not_found_intersection:
    index = lastfm_df.loc[lastfm_df['Artist'] == key].index
    lastfm_df = lastfm_df.drop(index)
    print(f"{key:<45} {possibly_wrong_mappings[key]:<70} \t {not_found_URIs[key]:<45}")
# Out:
# Deadmau5 & Wolfgang Gartner                   http://dbpedia.org/resource/Deadmau5                                   	 -1
# 7Seconds                                      http://dbpedia.org/resource/7_Seconds_(band)                           	 -1
# mono inc. & lisa middelhauve                  http://dbpedia.org/resource/Mono_Inc.                                  	 -1
# Yui Makino                                    http://dbpedia.org/resource/Yui_Makino                                 	 -1
# Beth Gibbons & Rustin Man                     http://dbpedia.org/resource/Beth_Gibbons                               	 -1
# The Weird Sisters                             http://dbpedia.org/resource/Three_Weird_Sisters_(band)                 	 -1
# Olu                                           http://dbpedia.org/resource/Olu_Dara                                   	 -1
# KRS-One & Marley Marl                         http://dbpedia.org/resource/KRS-One                                    	 -1
# Schock                                        http://dbpedia.org/resource/Gina_Schock                                	 -1
# Freeway & Jake One                            http://dbpedia.org/resource/Freeway_(rapper)                           	 -1
# Cassie Steele                                 http://dbpedia.org/resource/Cassie_Steele                              	 -1
# Pig & Dan                                     http://dbpedia.org/resource/Big_Pig                                    	 -1
# Claudia Leitte                                http://dbpedia.org/resource/Claudia_Leitte                             	 -1
# Julianne Hough                                http://dbpedia.org/resource/Julianne_Hough                             	 -1
# Ella Fitzgerald & Louis Armstrong             http://dbpedia.org/resource/Ella_Fitzgerald                            	 -1
# Anugama                                       http://dbpedia.org/resource/Anugama                                    	 -1
# Aus                                           http://dbpedia.org/resource/Aus-Rotten                                 	 -1
# Ulrich Schnauss & Jonas Munk                  http://dbpedia.org/resource/Ulrich_Schnauss                            	 -1
# Display                                       http://dbpedia.org/resource/The_Display_Team                           	 -1
# Vale                                          http://dbpedia.org/resource/Jerry_Vale                                 	 -1
# Everything Is Made in China                   http://dbpedia.org/resource/Everything_Is_Made_in_China                	 -1
# Bethany Joy Lenz                              http://dbpedia.org/resource/Bethany_Joy_Lenz                           	 -1
# Aura                                          http://dbpedia.org/resource/Aura_Noir                                  	 -1
# Fisz                                          http://dbpedia.org/resource/Fisz                                       	 -1
# Anna Netrebko                                 http://dbpedia.org/resource/Anna_Netrebko                              	 -1
# Valery & The Greedies                         http://dbpedia.org/resource/Valery_Meladze                             	 -1
# Bronski Beat & Marc Almond                    http://dbpedia.org/resource/Bronski_Beat                               	 -1
# Yuri & Mijares                                http://dbpedia.org/resource/Yuri_Chinen                                	 -1
# Ruth Flowers Mamy Rock                        http://dbpedia.org/resource/Ruth_Flowers                               	 -1
# Phillip Boa & The Voodooclub                  http://dbpedia.org/resource/Phillip_Boa                                	 -1
# Cortes                                        http://dbpedia.org/resource/Pamela_Cortes                              	 -1
# Mijares                                       http://dbpedia.org/resource/Luke_Mejares                               	 -1
# :wumpscut:                                    http://dbpedia.org/resource/Wumpscut:                                  	 -1
# Barbie                                        http://dbpedia.org/resource/Barbie_Almalbis                            	 -1
# Dirty Money                                   http://dbpedia.org/resource/Diddy_%E2%80%93_Dirty_Money                	 -1
# Mono & World's End Girlfriend                 http://dbpedia.org/resource/Mono_Band                                  	 -1
# John Legend & The Roots                       http://dbpedia.org/resource/John_Legend                                	 -1
# Mariah Carey & Whitney Houston                http://dbpedia.org/resource/Mariah_Carey                               	 -1
# K.C. And The Sunshine                         http://dbpedia.org/resource/KC_and_the_Sunshine_Band                   	 -1
# Mick Boogie & Terry Urban                     http://dbpedia.org/resource/MICK_(DJ)                                  	 -1
# Sonny Black & Frank White                     http://dbpedia.org/resource/Sonny_Black                                	 -1
# Mulan                                         http://dbpedia.org/resource/Mulan_Jameela                              	 -1
# dd/mm/yyyy                                    http://dbpedia.org/resource/DD/MM/YYYY                                 	 -1
# Luke                                          http://dbpedia.org/resource/Dr._Luke                                   	 -1
# Richard Walters                               http://dbpedia.org/resource/Slick_Rick                                 	 -1
# Marie & Nick                                  http://dbpedia.org/resource/Marie_Osmond                               	 -1
# The Author                                    http://dbpedia.org/resource/Robert_Palmer_(writer)                     	 -1
# Kazik                                         http://dbpedia.org/resource/Kazik_na_%25C5%25BBywo                     	 -1
# Chipmunk                                      http://dbpedia.org/resource/Chip_(rapper)                              	 -1
# They Shoot Horses Don't They                  http://dbpedia.org/resource/They_Shoot_Horses,_Don't_They%3F_(band)    	 -1
# Farhad                                        http://dbpedia.org/resource/Farhad_Mehrad                              	 -1
# Elton                                         http://dbpedia.org/resource/Elton_Ahi                                  	 -1
# xBishopx                                      http://dbpedia.org/resource/Bishop_(American_band)                     	 -1
# Hair                                          http://dbpedia.org/resource/Hair_Rocket                                	 -1
# Cujo                                          http://dbpedia.org/resource/Amon_Tobin                                 	 -1
# John Mayer & Taylor Swift                     http://dbpedia.org/resource/John_Mayer                                 	 -1
# ST                                            http://dbpedia.org/resource/St._Germain_(musician)                     	 -1
# The Vacation                                  http://dbpedia.org/resource/Sweet_Vacation                             	 -1
# Nick & Marie                                  http://dbpedia.org/resource/Nick_Cave                                  	 -1
# The Rock                                      http://dbpedia.org/resource/Pete_Rock                                  	 -1
# Peter Thomas                                  http://dbpedia.org/resource/Peter_Thomas_(producer)                    	 -1
# Ty Segall & Mikal Cronin                      http://dbpedia.org/resource/Ty_Segall                                  	 -1
# College                                       http://dbpedia.org/resource/David_Grellier__College_musical_project__1 	 -1
# Lili                                          http://dbpedia.org/resource/Lili_A%C3%B1el                             	 -1
# The Sect                                      http://dbpedia.org/resource/Sect_(Brazilian_band)                      	 -1
# Jack Black                                    http://dbpedia.org/resource/Jack_Black                                 	 -1
# Billy Corgan                                  http://dbpedia.org/resource/Billy_Corgan                               	 -1
# Seba                                          http://dbpedia.org/resource/Nujabes                                    	 -1
# Milton                                        http://dbpedia.org/resource/Roy_Milton                                 	 -1
# Perrey & Kingsley                             http://dbpedia.org/resource/Perrey_and_Kingsley                        	 -1
# Ganja Kru                                     http://dbpedia.org/resource/DJ_Hype                                    	 -1
# Josh Woodward                                 http://dbpedia.org/resource/Josh_Woodward                              	 -1
# Counterstrike & Current Value                 http://dbpedia.org/resource/Counterstrike_(drum_and_bass_group)        	 -1
# Paul & Linda McCartney                        http://dbpedia.org/resource/Paul_McCartney                             	 -1
# Julie London                                  http://dbpedia.org/resource/Julie_London                               	 -1
# Darkwood                                      http://dbpedia.org/resource/Darkwood_Dub                               	 -1
# Ordo Rosarius Equilibrio & Spiritual Front    http://dbpedia.org/resource/Ordo_Rosarius_Equilibrio                   	 -1
# Pride & Glory                                 http://dbpedia.org/resource/Pride_and_Glory_(band)                     	 -1
# State Of Mind & PNC                           http://dbpedia.org/resource/State_of_Mind_(band)                       	 -1
# Girlfriends                                   http://dbpedia.org/resource/The_Jealous_Girlfriends                    	 -1
# Terminator                                    http://dbpedia.org/resource/Johnny_Ace                                 	 -1
# GIR                                           http://dbpedia.org/resource/Piney_Gir                                  	 -1
# Selena Gomez & Demi Lovato                    http://dbpedia.org/resource/Selena_Gomez_&_the_Scene                   	 -1
# State Of Mind & Trei                          http://dbpedia.org/resource/State_of_Mind_(band)                       	 -1
# Joan Baez & Bob Dylan                         http://dbpedia.org/resource/Joan_Baez                                  	 -1
# Limewax & The Panacea                         http://dbpedia.org/resource/Limewax                                    	 -1
# Mash                                          http://dbpedia.org/resource/Kylian_Mash                                	 -1
# Martin O'Donnell & Michael Salvatori          http://dbpedia.org/resource/Martin_O'Donnell                           	 -1
# Edward Maya & Mia Martina                     http://dbpedia.org/resource/Edward_Maya                                	 -1
# Betty X                                       http://dbpedia.org/resource/Betty_X                                    	 -1
# Billie Holiday & Teddy Wilson & His Orchestra http://dbpedia.org/resource/Billie_Holiday                             	 -1
# Drake Bell                                    http://dbpedia.org/resource/Drake_Bell                                 	 -1
# Wolf Eyes & Black Dice                        http://dbpedia.org/resource/Wolf_Eyes                                  	 -1
# Corbin Bleu                                   http://dbpedia.org/resource/Corbin_Bleu                                	 -1
# Owls & Crows                                  http://dbpedia.org/resource/Owls_(band)                                	 -1
# Kayah                                         http://dbpedia.org/resource/Kayah_(singer)                             	 -1
# $lick                                         http://dbpedia.org/resource/Chikinki                                   	 -1
# EAR                                           http://dbpedia.org/resource/Kim_Thayil                                 	 -1
# PUMA                                          http://dbpedia.org/resource/Puma_Jones                                 	 -1
# Will Smith                                    http://dbpedia.org/resource/Patti_Smith                                	 -1
# Valentine                                     http://dbpedia.org/resource/Robby_Valentine                            	 -1
# Daggers                                       http://dbpedia.org/resource/Silver_Daggers                             	 -1
# Katherine                                     http://dbpedia.org/resource/Katherine_Ellis                            	 -1
# Lene                                          http://dbpedia.org/resource/Lene_Lovich                                	 -1
# Jan Garbarek Group                            http://dbpedia.org/resource/Jan_Garbarek                               	 -1
# Joe Strummer and The Mescaleros               http://dbpedia.org/resource/The_Mescaleros                             	 -1
# Fallen                                        http://dbpedia.org/resource/Fallen_To                                  	 -1
# Babylonia                                     http://dbpedia.org/resource/Inugami_Circus-dan                         	 -1
# Of The Fallen                                 http://dbpedia.org/resource/We_Are_the_Fallen                          	 -1
# The Dark                                      http://dbpedia.org/resource/Lisa_Lee_Dark                              	 -1
# Brian Eno & Jah Wobble                        http://dbpedia.org/resource/Brian_Eno                                  	 -1
# Rita Lee & Tutti Frutti                       http://dbpedia.org/resource/Rita_Lee                                   	 -1
# FREq                                          http://dbpedia.org/resource/Freq_Nasty                                 	 -1
# Vanda.                                        http://dbpedia.org/resource/Vanda_&_Young                              	 -1
# Axwell & Dirty South feat. Rudy               http://dbpedia.org/resource/Axwell                                     	 -1
# Devon Werkheiser                              http://dbpedia.org/resource/Devon_Werkheiser                           	 -1
# Lauren                                        http://dbpedia.org/resource/Lauren_Flax                                	 -1
# Brian Eno & J. Peter Schwalm                  http://dbpedia.org/resource/Brian_Eno                                  	 -1
# Daville                                       http://dbpedia.org/resource/Da'Ville                                   	 -1
# Rudenko                                       http://dbpedia.org/resource/Rudenko                                    	 -1
# Steve Angello & Laidback Luke                 http://dbpedia.org/resource/Steve_Angello                              	 -1
# Chris Lake & Micky Slim                       http://dbpedia.org/resource/Chris_Lake                                 	 -1
# Nevio                                         http://dbpedia.org/resource/Nevio_Passaro                              	 -1
# Jack White & Alicia Keys                      http://dbpedia.org/resource/Jack_White                                 	 -1
# The Vanishing                                 http://dbpedia.org/resource/Vanishing_Point_(band)                     	 -1
# Kissey Asplund                                http://dbpedia.org/resource/Kissey                                     	 -1
# Pink & Brown                                  http://dbpedia.org/resource/Pink_Anderson                              	 -1
# Steve Angello & Sebastian Ingrosso            http://dbpedia.org/resource/Steve_Angello                              	 -1
# Rex Garvin & The Mighty Cravers               http://dbpedia.org/resource/Rex_Garvin                                 	 -1
# Derdian                                       http://dbpedia.org/resource/Derdian                                    	 -1
# Renard                                        http://dbpedia.org/resource/Doraine_and_Ellis                          	 -1
# Drew Seeley                                   http://dbpedia.org/resource/Drew_Seeley                                	 -1
# Darwin & Fracus featuring Ant                 http://dbpedia.org/resource/Darwin_Symphony_Orchestra                  	 -1
# The Champions                                 http://dbpedia.org/resource/Futuristic_Retro_Champions                 	 -1
# Dougal & Gammer                               http://dbpedia.org/resource/DJ_Dougal                                  	 -1
# Victor & Léo                                  http://dbpedia.org/resource/Victor_Young                               	 -1
# David Russell                                 http://dbpedia.org/resource/Dave_Davies                                	 -1
# Mitchel Musso                                 http://dbpedia.org/resource/Mitchel_Musso                              	 -1
# Why?                                          http://dbpedia.org/resource/Why%3F_(American_band)                     	 -1
# Johnny Jones & The King Casuals               http://dbpedia.org/resource/Little_Johnny_Jones_(pianist)              	 -1
# Sum                                           http://dbpedia.org/resource/Sum_41                                     	 -1
# Serge Gainsbourg & Brigitte Bardot            http://dbpedia.org/resource/Serge_Gainsbourg                           	 -1
# Scorpions & Berliner Philharmoniker           http://dbpedia.org/resource/Scorpions_(band)                           	 -1
# Duncan Sheik & Steven Sater                   http://dbpedia.org/resource/Duncan_Sheik                               	 -1
# Erika                                         http://dbpedia.org/resource/Erika_Heynatz                              	 -1
# The Milo                                      http://dbpedia.org/resource/Yano                                       	 -1
# The Pianist                                   http://dbpedia.org/resource/Video_Game_Pianist                         	 -1
# Rocco DeLuca & The Burden                     http://dbpedia.org/resource/Rocco_Deluca                               	 -1
# 7th Floor                                     http://dbpedia.org/resource/Paul_Nicholas                              	 -1
# Justin Young                                  http://dbpedia.org/resource/Justin_(singer)                            	 -1
# Bono & The Mdh Band                           http://dbpedia.org/resource/Bono                                       	 -1
# Dr. Who Dat?                                  http://dbpedia.org/resource/Jneiro_Jarel                               	 -1
# Elton John & Hans Zimmer & Lebo M & South African Chorus http://dbpedia.org/resource/Elton_John                                 	 -1
# JME                                           http://dbpedia.org/resource/JME_(rapper)                               	 -1
# Jelonek                                       http://dbpedia.org/resource/Micha%C5%82_Jelonek                        	 -1
# The Trees & The Wild                          http://dbpedia.org/resource/Trees_&_Wild                               	 -1
# Jammer                                        http://dbpedia.org/resource/Jammer_(rapper)                            	 -1
# No_Mad                                        http://dbpedia.org/resource/Kendrick_Lamar                             	 -1
# Sam Tsui & Christina Grimmie                  http://dbpedia.org/resource/Sam_Tsui                                   	 -1
# Holger                                        http://dbpedia.org/resource/Holger_Hiller                              	 -1
# King Khan & The Shrines                       http://dbpedia.org/resource/King_Khan_and_the_Shrines                  	 -1
# Bo Burnham                                    http://dbpedia.org/resource/Bo_Burnham                                 	 -1
# Luigi Masi                                    http://dbpedia.org/resource/Luigi_Masi                                 	 -1
# Yolanda Be Cool & DCUP                        http://dbpedia.org/resource/Yolanda_Be_Cool                            	 -1
# Killwhitneydead                               http://dbpedia.org/resource/Killwhitneydead                            	 -1
# Aida                                          http://dbpedia.org/resource/Aida_Nadeem                                	 -1
# Benedetti & Svoboda                           http://dbpedia.org/resource/Myria_Benedetti                            	 -1
# Marius                                        http://dbpedia.org/resource/Marius_Moga                                	 -1
# Tigarah                                       http://dbpedia.org/resource/Tigarah                                    	 -1
# The Up On In                                  http://dbpedia.org/resource/The_Get_Up_Kids                            	 -1
# Skywave                                       http://dbpedia.org/resource/Simon_William_Lord                         	 -1
# Stunt                                         http://dbpedia.org/resource/Steve_Vai                                  	 -1
# Johnny Cash & Willie Nelson                   http://dbpedia.org/resource/Johnny_Cash                                	 -1
# Cinta Laura                                   http://dbpedia.org/resource/Cinta_Laura                                	 -1
# Harland                                       http://dbpedia.org/resource/Kurt_Harland                               	 -1
# stellastarr*                                  http://dbpedia.org/resource/Stellastarr                                	 -1
# The Actor                                     http://dbpedia.org/resource/Jack_Wagner_(actor)                        	 -1
# Johnny Hammond                                http://dbpedia.org/resource/Johnny_%22Hammond%22_Smith                 	 -1
# Sandro                                        http://dbpedia.org/resource/Sandro_de_Am%C3%A9rica                     	 -1
# Tristan                                       http://dbpedia.org/resource/Tristan_D                                  	 -1
# Dick Dale and His Del-Tones                   http://dbpedia.org/resource/Dick_Dale                                  	 -1
# Edda                                          http://dbpedia.org/resource/Edda_M%C5%B1vek                            	 -1
# Donny                                         http://dbpedia.org/resource/Don_Airey                                  	 -1
# Brian Eno & David Byrne                       http://dbpedia.org/resource/Brian_Eno                                  	 -1
# bassment                                      http://dbpedia.org/resource/Basement_Jaxx                              	 -1
# Bridges                                       http://dbpedia.org/resource/The_Bridges_(band)                         	 -1
# Gorilla                                       http://dbpedia.org/resource/Gorillaz                                   	 -1
# Tyrese                                        http://dbpedia.org/resource/Tyrese_Gibson                              	 -1
# Drum Theatre                                  http://dbpedia.org/resource/Drum_Theatre                               	 -1
# Sydney                                        http://dbpedia.org/resource/Sydney_Blu                                 	 -1
# Kyrie                                         http://dbpedia.org/resource/Kyrie_Kristmanson                          	 -1
# Roxx                                          http://dbpedia.org/resource/Roxx_Gang                                  	 -1
# FC/Kahuna                                     http://dbpedia.org/resource/FC_Kahuna                                  	 -1
# AXiS & Trank                                  http://dbpedia.org/resource/Axis_of_Advance                            	 -1
# Peep Show                                     http://dbpedia.org/resource/Sikth                                      	 -1
# Cora                                          http://dbpedia.org/resource/Tom_Cora                                   	 -1
# Wirtz                                         http://dbpedia.org/resource/Reverend_Billy_C._Wirtz                    	 -1
# JAW                                           http://dbpedia.org/resource/Tigers_Jaw                                 	 -1
# Helios                                        http://dbpedia.org/resource/Helios_Creed                               	 -1
# D:Ream                                        http://dbpedia.org/resource/D:Ream                                     	 -1
# The Uniform                                   http://dbpedia.org/resource/The_Pipettes                               	 -1
# Delirious?                                    http://dbpedia.org/resource/Delirious%3F                               	 -1
# Oblique                                       http://dbpedia.org/resource/Corde_Oblique                              	 -1
# Sonny Black & Saad                            http://dbpedia.org/resource/Sonny_Black                                	 -1
# Dylan                                         http://dbpedia.org/resource/Bob_Dylan                                  	 -1
# Paul B                                        http://dbpedia.org/resource/Paul_B                                     	 -1
# Billy Bragg and The Blokes                    http://dbpedia.org/resource/Billy_Bragg                                	 -1
# Favorite & Hollywood Hank                     http://dbpedia.org/resource/My_Favorite_Highway                        	 -1
# Love Generation                               http://dbpedia.org/resource/Stockholm_Syndrome_(group)                 	 -1
# Futon                                         http://dbpedia.org/resource/Futon_(band)                               	 -1
# UniKKatiL                                     http://dbpedia.org/resource/Unikkatil                                  	 -1
# Johnny Marr + the Healers                     http://dbpedia.org/resource/Johnny_Marr                                	 -1
# Aidan Baker & thisquietarmy                   http://dbpedia.org/resource/Aidan_Baker                                	 -1
# Does It Offend You, Yeah?                     http://dbpedia.org/resource/Does_It_Offend_You,_Yeah%3F                	 -1
# Out Out                                       http://dbpedia.org/resource/Shout_Out_Out_Out_Out                      	 -1
# O+S                                           http://dbpedia.org/resource/O.S.T.R.                                   	 -1
# Gram                                          http://dbpedia.org/resource/Gram_Rabbit                                	 -1
# Run Level Zero                                http://dbpedia.org/resource/Run_Level_Zero                             	 -1
# Bryan Ferry & Roxy Music                      http://dbpedia.org/resource/Bryan_Ferry                                	 -1
# Blank                                         http://dbpedia.org/resource/Cold_Blank                                 	 -1
# Last & Galle                                  http://dbpedia.org/resource/The_Last_Shadow_Puppets                    	 -1
# Idina Menzel                                  http://dbpedia.org/resource/Idina_Menzel                               	 -1
# Skye                                          http://dbpedia.org/resource/Skye_Edwards                               	 -1
# Troy & Gabriella                              http://dbpedia.org/resource/Troy_Sanders                               	 -1
# Alyson Stoner                                 http://dbpedia.org/resource/Alyson_Stoner                              	 -1
# talley trio                                   http://dbpedia.org/resource/The_Talleys                                	 -1
# Timbaland feat. Keri Hilson & Sebastian       http://dbpedia.org/resource/Timbaland                                  	 -1
# Rocco                                         http://dbpedia.org/resource/Rocco_Deluca                               	 -1
# Frank Zappa & Captain Beefheart               http://dbpedia.org/resource/Frank_Zappa                                	 -1
# Marin                                         http://dbpedia.org/resource/Orlando_Marin                              	 -1
# The Boats                                     http://dbpedia.org/resource/New_Rules_for_Boats                        	 -1
# KOTOKO                                        http://dbpedia.org/resource/Kotoko_(singer)                            	 -1
# Cee-Lo                                        http://dbpedia.org/resource/CeeLo_Green                                	 -1
# Ast & Kralle                                  http://dbpedia.org/resource/Haras_Fyre__ast_CoastfeaturingGwen_Guthrie__1 	 -1
# Timbaland feat. Keri Hilson & D.O.E.          http://dbpedia.org/resource/Timbaland                                  	 -1
# Heart To Heart                                http://dbpedia.org/resource/Heart_2_Heart_(band)                       	 -1
# Chiasm                                        http://dbpedia.org/resource/Emileigh_Rohn                              	 -1
# Solange                                       http://dbpedia.org/resource/Solange_Knowles                            	 -1
# El Da Sensei & Returners                      http://dbpedia.org/resource/El_Da_Sensei                               	 -1
# Sam                                           http://dbpedia.org/resource/Samanda                                    	 -1
# Enlightenment                                 http://dbpedia.org/resource/Orchestra_of_the_Age_of_Enlightenment      	 -1
# The Crowns                                    http://dbpedia.org/resource/Crowns_(band)                              	 -1
# Battleship                                    http://dbpedia.org/resource/Battleship_(band)                          	 -1
# Du                                            http://dbpedia.org/resource/Du_Du_A                                    	 -1
# w-inds.                                       http://dbpedia.org/resource/W-inds                                     	 -1
# Lisa & Jessica                                http://dbpedia.org/resource/Lisa_Lopes                                 	 -1
# SE7EN                                         http://dbpedia.org/resource/Seven_(Korean_singer)                      	 -1
# Johnny Flynn & the Sussex Wit                 http://dbpedia.org/resource/Johnny_Flynn                               	 -1
# Yamashita Tomohisa & Ikuta Toma               http://dbpedia.org/resource/Tomohisa_Yamashita                         	 -1
# Museum                                        http://dbpedia.org/resource/Sex_Museum_(band)                          	 -1
# Drew Seeley & Selena Gomez                    http://dbpedia.org/resource/Drew_Seeley                                	 -1
# Lynn Johnson                                  http://dbpedia.org/resource/Meshell_Ndegeocello                        	 -1
# Ashley Tisdale & Lucas Grabeel                http://dbpedia.org/resource/Ashley_Tisdale                             	 -1
# Passengers                                    http://dbpedia.org/resource/The_Passengers_(band)                      	 -1
# John Taylor                                   http://dbpedia.org/resource/John_C._J._Taylor                          	 -1
# 6.Cadde                                       http://dbpedia.org/resource/6._Cadde                                   	 -1
# Demons & Wizards                              http://dbpedia.org/resource/Demons_and_Wizards_(band)                  	 -1
# Datach'i                                      http://dbpedia.org/resource/Datach'i                                   	 -1
# Inactive Messiah                              http://dbpedia.org/resource/Inactive_Messiah                           	 -1
# Wicked                                        http://dbpedia.org/resource/Wicked_Lester                              	 -1
# Beta                                          http://dbpedia.org/resource/Beta_Radio                                 	 -1
# Stephanie                                     http://dbpedia.org/resource/Stephanie_Davis                            	 -1
# Leela                                         http://dbpedia.org/resource/P._Leela                                   	 -1
# Fuat                                          http://dbpedia.org/resource/Mazhar-Fuat-%C3%96zkan                     	 -1
# Fatale                                        http://dbpedia.org/resource/Femme_Fatale_(American_band)               	 -1
# Mandy Moore                                   http://dbpedia.org/resource/Mandy_Moore                                	 -1
# Antony Raijekov                               http://dbpedia.org/resource/Antony_Raijekov                            	 -1
# Restless                                      http://dbpedia.org/resource/Restless_Heart                             	 -1
# Toxic                                         http://dbpedia.org/resource/Toxic_Waste_(band)                         	 -1
# Elin                                          http://dbpedia.org/resource/Elin_Sigvardsson                           	 -1
# Humberto & Ronaldo                            http://dbpedia.org/resource/Humberto_Bruni_Lamanna                     	 -1
# Ricky Martin & Christina Aguilera             http://dbpedia.org/resource/Ricky_Martin                               	 -1
# twin cities                                   http://dbpedia.org/resource/Twin_Cities_Gay_Men's_Chorus               	 -1
# Joseph Arthur & the Lonely Astronauts         http://dbpedia.org/resource/Joseph_Arthur                              	 -1
# John Powell                                   http://dbpedia.org/resource/John_Powell                                	 -1
# Tulsa                                         http://dbpedia.org/resource/Tulsa_Symphony                             	 -1
# Belinda                                       http://dbpedia.org/resource/Belinda_Peregr%25C3%25ADn                  	 -1
# Baaba Maal & Mansour Seck                     http://dbpedia.org/resource/Baaba_Maal                                 	 -1
# Hannah Montana                                http://dbpedia.org/resource/Miley_Cyrus                                	 -1
# Gringo                                        http://dbpedia.org/resource/Baby_Rasta_&_Gringo                        	 -1
# Jets                                          http://dbpedia.org/resource/The_Jets_(Minnesota_band)                  	 -1
# Mancini                                       http://dbpedia.org/resource/Dan_Mancini                                	 -1
# __MaX__                                       http://dbpedia.org/resource/Max_Martin                                 	 -1
# Urban Myth Club                               http://dbpedia.org/resource/Urban_Myth_Club                            	 -1
# Shreya Ghoshal & Shaan                        http://dbpedia.org/resource/Shreya_Ghoshal                             	 -1
# K.K.                                          http://dbpedia.org/resource/KK_(singer)                                	 -1
# Emily Osment                                  http://dbpedia.org/resource/Emily_Osment                               	 -1
# The Zombi                                     http://dbpedia.org/resource/Zombi_(band)                               	 -1
# Geri Halliwell                                http://dbpedia.org/resource/Geri_Halliwell                             	 -1
# Herb Alpert and The Tijuana Brass             http://dbpedia.org/resource/Herb_Alpert                                	 -1
# Eliana                                        http://dbpedia.org/resource/Eliana_Printes                             	 -1
# ...
# Days                                          http://dbpedia.org/resource/28_Days                                    	 -1
# f(x)                                          http://dbpedia.org/resource/F(x)_(band)                                	 -1
# Carfax Abbey                                  http://dbpedia.org/resource/Dracula                                    	 -1
# RoBERT                                        http://dbpedia.org/resource/Robert_Rich_(musician)                     	 -1
# Ass                                           http://dbpedia.org/resource/Ass_Ponys                                  	 -1
# The Search                                    http://dbpedia.org/resource/Shulman_(band)                             	 -1
# Cosma                                         http://dbpedia.org/resource/Vladimir_Cosma                             	 -1
# MC Lars & YTCracker                           http://dbpedia.org/resource/MC_Lars                                    	 -1
# Hassan Hakmoun & Adam Rudolph                 http://dbpedia.org/resource/Hassan_Hakmoun                             	 -1
# Warda                                         http://dbpedia.org/resource/Warda_Al-Jazairia                          	 -1
# The Brides                                    http://dbpedia.org/resource/The_June_Brides                            	 -1
# Rafael                                        http://dbpedia.org/resource/AJ_Rafael                                  	 -1
# Bedford                                       http://dbpedia.org/resource/David_Bedford                              	 -1
# No Tears                                      http://dbpedia.org/resource/The_Tears                                  	 -1
# Robert M                                      http://dbpedia.org/resource/Robert_M._Rucker                           	 -1
# Uniform                                       http://dbpedia.org/resource/The_Pipettes                               	 -1
# The Blizzard                                  http://dbpedia.org/resource/The_Blizzards                              	 -1
# Birdman                                       http://dbpedia.org/resource/Radio_Birdman                              	 -1
# Porter Band                                   http://dbpedia.org/resource/Porter_(band)                              	 -1
# PGR                                           http://dbpedia.org/resource/Kim_Cascone                                	 -1
# Jennette McCurdy                              http://dbpedia.org/resource/Jennette_McCurdy                           	 -1
# Susana                                        http://dbpedia.org/resource/Susana_Harp                                	 -1
# Nat King Cole & Natalie Cole                  http://dbpedia.org/resource/Nat_King_Cole                              	 -1
# Richy Nix                                     http://dbpedia.org/resource/Richy_Nix                                  	 -1
# 8th                                           http://dbpedia.org/resource/The_8th_Horcrux                            	 -1
# Victoria Justice                              http://dbpedia.org/resource/Victoria_Justice                           	 -1
# Fake                                          http://dbpedia.org/resource/Fake%3F                                    	 -1
# [unknown]                                     http://dbpedia.org/resource/Pop_Unknown                                	 -1
# Santos                                        http://dbpedia.org/resource/Lulu_Santos                                	 -1
# Jayne Mansfield                               http://dbpedia.org/resource/Jayne_Mansfield__Jayne_Mansfield__2        	 -1
# Afterlife                                     http://dbpedia.org/resource/Afterlife_(musician)                       	 -1
# III                                           http://dbpedia.org/resource/Bob_Log_III                                	 -1
# Bobby Brown                                   http://dbpedia.org/resource/Bobby_Brown                                	 -1
# Above&Beyond Presents Oceanlab                http://dbpedia.org/resource/OceanLab                                   	 -1
# T.A.T.U                                       http://dbpedia.org/resource/T.A.T.u.                                   	 -1
# Guns N Roses &Alice Cooper                    http://dbpedia.org/resource/Guns_N'_Roses                              	 -1
# A.F.I.                                        http://dbpedia.org/resource/AFI_(band)                                 	 -1
# Motor                                         http://dbpedia.org/resource/El_Motor                                   	 -1
# Phutureprimitive                              http://dbpedia.org/resource/Phutureprimitive                           	 -1
# Osborne                                       http://dbpedia.org/resource/Mike_Osborne                               	 -1
# Essence                                       http://dbpedia.org/resource/Rare_Essence                               	 -1
# Let's Get It                                  http://dbpedia.org/resource/Ace_Hood                                   	 -1
# Raz                                           http://dbpedia.org/resource/Raz-B                                      	 -1
# Nahash                                        http://dbpedia.org/resource/Hadag_Nahash                               	 -1
# S.O.D.                                        http://dbpedia.org/resource/Stormtroopers_of_Death                     	 -1
# Klein & Mbo                                   http://dbpedia.org/resource/Klein_+_M.B.O.                             	 -1
# Jesse McCartney                               http://dbpedia.org/resource/Jesse_McCartney                            	 -1
# W.K.?                                         http://dbpedia.org/resource/Andrew_W.K.                                	 -1
# Tua                                           http://dbpedia.org/resource/In_Tua_Nua                                 	 -1
# Now                                           http://dbpedia.org/resource/Nightwish                                  	 -1
# Justin Hinds & The Dominoes                   http://dbpedia.org/resource/Justin_Hinds                               	 -1
# Uzi & Ari                                     http://dbpedia.org/resource/Uzi_and_Ari                                	 -1
# Nazar & Raf Camora                            http://dbpedia.org/resource/Nazar_(rapper)                             	 -1
# Provision                                     http://dbpedia.org/resource/Provision_(musical_group)                  	 -1
# Taichi                                        http://dbpedia.org/resource/Taichi_Kokubun                             	 -1
# Urban & 4                                     http://dbpedia.org/resource/Urbandub                                   	 -1
# Blue                                          http://dbpedia.org/resource/Labelle                                    	 -1
# Teitur                                        http://dbpedia.org/resource/Teitur_Lassen                              	 -1
# Lollobrigida                                  http://dbpedia.org/resource/Lollobrigida_Girls                         	 -1
# Saad                                          http://dbpedia.org/resource/Hoda_Saad                                  	 -1
# Borys                                         http://dbpedia.org/resource/Stan_Borys                                 	 -1
# Foundation                                    http://dbpedia.org/resource/K_Foundation                               	 -1
# Dr. Ring-Ding & The Senior Allstars           http://dbpedia.org/resource/Dr._Ring-Ding                              	 -1
# nevershoutnever!                              http://dbpedia.org/resource/Never_Shout_Never                          	 -1
# Eddie                                         http://dbpedia.org/resource/Eddie_Money                                	 -1
# Jason Walker                                  http://dbpedia.org/resource/Jason_Walker_(musician)                    	 -1
# Merda                                         http://dbpedia.org/resource/Black_Merda                                	 -1
# melody.                                       http://dbpedia.org/resource/Melody_(Spanish_singer)                    	 -1
# Chaves                                        http://dbpedia.org/resource/Ram_Chaves                                 	 -1
# Nick Cave & Warren Ellis                      http://dbpedia.org/resource/Nick_Cave_and_the_Bad_Seeds                	 -1
# Hick                                          http://dbpedia.org/resource/Six_Ft_Hick                                	 -1
# Flora                                         http://dbpedia.org/resource/Flora_Purim                                	 -1
# Does It Offend You Yeah?                      http://dbpedia.org/resource/Does_It_Offend_You,_Yeah%3F                	 -1
# Axel Fernando                                 http://dbpedia.org/resource/Axel_(singer)                              	 -1
# Pamela                                        http://dbpedia.org/resource/Pamela_Spence                              	 -1
# In Irons                                      http://dbpedia.org/resource/Jack_Irons                                 	 -1
# Demi Lovato & Joe Jonas                       http://dbpedia.org/resource/Demi_Lovato                                	 -1
# Zombie                                        http://dbpedia.org/resource/Rob_Zombie                                 	 -1
# 13                                            http://dbpedia.org/resource/Nick_13                                    	 -1
# John Mayall & The Bluesbreakers Featuring Buddy Guy http://dbpedia.org/resource/John_Mayall_&_the_Bluesbreakers            	 -1
# The Good, the Bad & the Queen                 http://dbpedia.org/resource/The_Good_The_Bad                           	 -1
# Roger Miller                                  http://dbpedia.org/resource/Roger_Miller                               	 -1
# Rod Piazza & The Blues Instigators            http://dbpedia.org/resource/Rod_Piazza                                 	 -1
# GT & The Bandits                              http://dbpedia.org/resource/Logobi_GT                                  	 -1
# she                                           http://dbpedia.org/resource/Van_She                                    	 -1
# A Radio With Guts                             http://dbpedia.org/resource/The_Connie_Dungs                           	 -1
# Highway                                       http://dbpedia.org/resource/Highway_101                                	 -1
# John Petrucci & Jordan Rudess                 http://dbpedia.org/resource/John_Petrucci                              	 -1
# The String Quartet                            http://dbpedia.org/resource/Enso_String_Quartet                        	 -1
# Imagica                                       http://dbpedia.org/resource/The_Birthday_Massacre                      	 -1
# Juelz Santana & Lil Wayne                     http://dbpedia.org/resource/Juelz_Santana                              	 -1
# theaudience                                   http://dbpedia.org/resource/Theaudience                                	 -1
# Jeffree Star                                  http://dbpedia.org/resource/Jeffree_Star                               	 -1
# Nicole Scherzinger                            http://dbpedia.org/resource/Nicole_Scherzinger                         	 -1
# Sonny Boy Williamson                          http://dbpedia.org/resource/Sonny_Boy_Williamson_(original)            	 -1
# Joyce & Ridge                                 http://dbpedia.org/resource/Joyce_Sims                                 	 -1
# Sibel                                         http://dbpedia.org/resource/Sibel_Red%C5%BEep                          	 -1

# %%
# Check if duplicates exist
lastfm_df[lastfm_df.duplicated(['URI'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [ID, Artist, URI]
# Index: []

# %% [markdown]
# ## Make the Update

# %%
lastfm_df.to_csv('./lastfm/Mapping2DBpedia-1.2-corrected.tsv', sep='\t', index = False, header = False, encoding="utf-8")
